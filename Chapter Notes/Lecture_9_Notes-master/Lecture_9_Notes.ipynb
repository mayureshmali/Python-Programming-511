# %% [markdown]
# ## Web APIs

# %% [markdown]
# ### How to build out an API using variables and strings

# %%
# The base URI address
base_uri = "https://api.github.com"

# URI variables (if any)
username = "infx511"

# The specific endpoint of the address
resource = "/users/" + username + "/repos"

# The complete URI
uri = base_uri + resource

# %% [markdown]
# Now print it

# %%
uri

# %% [markdown]
# ## How to call an API using Python get() method

# %%
# import the module
import requests

# GET request for iSchool home page
requests.get("https://ischool.uw.edu/")

# GET request to search google
query_params = {"q": "informatics"}  # query parameters are a dict
requests.get("https://www.google.com/search", params = query_params)
# Out:
# <Response [200]>

# %%
# define URI in parts for easy changing
base_uri = "https://api.github.com"
resource = "/users/"+"infx511"+"/repos"

# GET request for GitHub repos
response = requests.get(base_uri+resource)

# print the response received
print(response)  # <Response [200]>, we got a response
# Out:
# <Response [200]>

# %%
#get the status code for this repsponse
response.status_code
# Out:
# 200

# %%
#What url did my response get sent to?
response.url
# Out:
# 'https://api.github.com/users/infx511/repos'

# %%
header = response.headers
header
# Out:
# {'Date': 'Sun, 03 Mar 2019 01:18:19 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Server': 'GitHub.com', 'Status': '200 OK', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '55', 'X-RateLimit-Reset': '1551577231', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding', 'ETag': 'W/"26f121f2181fcd16c6b585f580977b0f"', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': 'F177:1B0F:216FBE9:28BE42D:5C7B2B5A'}

# %% [markdown]
# What data type is this response?

# %%
text_data = response.text
print(text_data)
# Out:
# [{"id":125927690,"node_id":"MDEwOlJlcG9zaXRvcnkxMjU5Mjc2OTA=","name":"book","full_name":"infx511/book","private":false,"owner":{"login":"infx511","id":34052090,"node_id":"MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw","avatar_url":"https://avatars0.githubusercontent.com/u/34052090?v=4","gravatar_id":"","url":"https://api.github.com/users/infx511","html_url":"https://github.com/infx511","followers_url":"https://api.github.com/users/infx511/followers","following_url":"https://api.github.com/users/infx511/following{/other_user}","gists_url":"https://api.github.com/users/infx511/gists{/gist_id}","starred_url":"https://api.github.com/users/infx511/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/infx511/subscriptions","organizations_url":"https://api.github.com/users/infx511/orgs","repos_url":"https://api.github.com/users/infx511/repos","events_url":"https://api.github.com/users/infx511/events{/privacy}","received_events_url":"https://api.github.com/users/infx511/received_events","type":"Organization","site_admin":false},"html_url":"https://github.com/infx511/book","description":"Source code for the course book","fork":false,"url":"https://api.github.com/repos/infx511/book","forks_url":"https://api.github.com/repos/infx511/book/forks","keys_url":"https://api.github.com/repos/infx511/book/keys{/key_id}","collaborators_url":"https://api.github.com/repos/infx511/book/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/infx511/book/teams","hooks_url":"https://api.github.com/repos/infx511/book/hooks","issue_events_url":"https://api.github.com/repos/infx511/book/issues/events{/number}","events_url":"https://api.github.com/repos/infx511/book/events","assignees_url":"https://api.github.com/repos/infx511/book/assignees{/user}","branches_url":"https://api.github.com/repos/infx511/book/branches{/branch}","tags_url":"https://api.github.com/repos/infx511/book/tags","blobs_url":"https://api.github.com/repos/infx511/book/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/infx511/book/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/infx511/book/git/refs{/sha}","trees_url":"https://api.github.com/repos/infx511/book/git/trees{/sha}","statuses_url":"https://api.github.com/repos/infx511/book/statuses/{sha}","languages_url":"https://api.github.com/repos/infx511/book/languages","stargazers_url":"https://api.github.com/repos/infx511/book/stargazers","contributors_url":"https://api.github.com/repos/infx511/book/contributors","subscribers_url":"https://api.github.com/repos/infx511/book/subscribers","subscription_url":"https://api.github.com/repos/infx511/book/subscription","commits_url":"https://api.github.com/repos/infx511/book/commits{/sha}","git_commits_url":"https://api.github.com/repos/infx511/book/git/commits{/sha}","comments_url":"https://api.github.com/repos/infx511/book/comments{/number}","issue_comment_url":"https://api.github.com/repos/infx511/book/issues/comments{/number}","contents_url":"https://api.github.com/repos/infx511/book/contents/{+path}","compare_url":"https://api.github.com/repos/infx511/book/compare/{base}...{head}","merges_url":"https://api.github.com/repos/infx511/book/merges","archive_url":"https://api.github.com/repos/infx511/book/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/infx511/book/downloads","issues_url":"https://api.github.com/repos/infx511/book/issues{/number}","pulls_url":"https://api.github.com/repos/infx511/book/pulls{/number}","milestones_url":"https://api.github.com/repos/infx511/book/milestones{/number}","notifications_url":"https://api.github.com/repos/infx511/book/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/infx511/book/labels{/name}","releases_url":"https://api.github.com/repos/infx511/book/releases{/id}","deployments_url":"https://api.github.com/repos/infx511/book/deployments","created_at":"2018-03-19T22:19:55Z","updated_at":"2018-05-16T19:26:18Z","pushed_at":"2018-05-16T19:26:16Z","git_url" ...

# %%
type(text_data)
# Out:
# str

# %%
binary_data = response.content
type(binary_data)
# Out:
# bytes

# %%
json_data = response.json
type(json_data)
# Out:
# method

# %% [markdown]
# ## Import JSON Library and work with it

# %%
import json

# %%
## loads() produces something that's a little more agreeable
my_data = json.loads(text_data)
type(my_data)

#produces a list of dictionaries
# Out:
# list

# %%
my_data[:100]
# Out:
# [{'id': 125927690,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMjU5Mjc2OTA=',
#   'name': 'book',
#   'full_name': 'infx511/book',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/book',
#   'description': 'Source code for the course book',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/book',
#   'forks_url': 'https://api.github.com/repos/infx511/book/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/book/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/book/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/book/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/book/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/book/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/book/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/book/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/book/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/book/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/book/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/book/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/book/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/book/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/book/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/book/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/book/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/book/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/book/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/book/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/book/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/book/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/book/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/book/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/book/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/book/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/book/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/book/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/book/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/book/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/book/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/book/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/book/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/book/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/book/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/book/deployments',
#   'created_at': '2018-03-19T22:19:55Z',
#   'updated_at': '2018-05-16T19:26:18Z',
#   'pushed_at': '2018-05-16T19:26:16Z',
#   'git_url': 'git://github.com/infx511/book.git',
#   'ssh_url': 'git@github.com:infx511/book.git',
#   'clone_url': 'https://github.com/infx511/book.git',
#   'svn_url': 'https://github.com/infx511/book',
#   'homepage': None,
#   'size': 13164,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 132556531,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzI1NTY1MzE=',
#   'name': 'branch_practice',
#   'full_name': 'infx511/branch_practice',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/branch_practice',
#   'description': 'An example repo for practicing with git branches',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/branch_practice',
#   'forks_url': 'https://api.github.com/repos/infx511/branch_practice/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/branch_practice/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/branch_practice/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/branch_practice/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/branch_practice/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/branch_practice/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/branch_practice/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/branch_practice/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/branch_practice/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/branch_practice/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/branch_practice/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/branch_practice/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/branch_practice/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/branch_practice/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/branch_practice/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/branch_practice/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/branch_practice/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/branch_practice/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/branch_practice/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/branch_practice/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/branch_practice/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/branch_practice/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/branch_practice/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/branch_practice/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/branch_practice/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/branch_practice/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/branch_practice/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/branch_practice/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/branch_practice/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/branch_practice/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/branch_practice/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/branch_practice/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/branch_practice/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/branch_practice/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/branch_practice/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/branch_practice/deployments',
#   'created_at': '2018-05-08T05:05:37Z',
#   'updated_at': '2018-05-08T05:06:03Z',
#   'pushed_at': '2018-05-08T05:06:03Z',
#   'git_url': 'git://github.com/infx511/branch_practice.git',
#   'ssh_url': 'git@github.com:infx511/branch_practice.git',
#   'clone_url': 'https://github.com/infx511/branch_practice.git',
#   'svn_url': 'https://github.com/infx511/branch_practice',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 17,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 17,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 129773013,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMjk3NzMwMTM=',
#   'name': 'ch10-searching',
#   'full_name': 'infx511/ch10-searching',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/ch10-searching',
#   'description': 'Exercises for Chapter 10: Searching and Efficiency',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/ch10-searching',
#   'forks_url': 'https://api.github.com/repos/infx511/ch10-searching/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/ch10-searching/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/ch10-searching/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/ch10-searching/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/ch10-searching/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/ch10-searching/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/ch10-searching/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/ch10-searching/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/ch10-searching/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/ch10-searching/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/ch10-searching/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/ch10-searching/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/ch10-searching/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/ch10-searching/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/ch10-searching/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/ch10-searching/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/ch10-searching/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/ch10-searching/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/ch10-searching/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/ch10-searching/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/ch10-searching/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/ch10-searching/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/ch10-searching/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/ch10-searching/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/ch10-searching/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/ch10-searching/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/ch10-searching/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/ch10-searching/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/ch10-searching/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/ch10-searching/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/ch10-searching/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/ch10-searching/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/ch10-searching/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/ch10-searching/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/ch10-searching/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/ch10-searching/deployments',
#   'created_at': '2018-04-16T16:23:11Z',
#   'updated_at': '2018-04-16T16:30:49Z',
#   'pushed_at': '2018-04-16T16:30:43Z',
#   'git_url': 'git://github.com/infx511/ch10-searching.git',
#   'ssh_url': 'git@github.com:infx511/ch10-searching.git',
#   'clone_url': 'https://github.com/infx511/ch10-searching.git',
#   'svn_url': 'https://github.com/infx511/ch10-searching',
#   'homepage': None,
#   'size': 330,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 34,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 34,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 129775200,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMjk3NzUyMDA=',
#   'name': 'ch11-functional-programming',
#   'full_name': 'infx511/ch11-functional-programming',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/ch11-functional-programming',
#   'description': 'Exercises for Chapter 11: Functional Programming',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/ch11-functional-programming',
#   'forks_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/ch11-functional-programming/deployments',
#   'created_at': '2018-04-16T16:40:21Z',
#   'updated_at': '2018-04-16T16:40:45Z',
#   'pushed_at': '2018-04-16T16:40:44Z',
#   'git_url': 'git://github.com/infx511/ch11-functional-programming.git',
#   'ssh_url': 'git@github.com:infx511/ch11-functional-programming.git',
#   'clone_url': 'https://github.com/infx511/ch11-functional-programming.git',
#   'svn_url': 'https://github.com/infx511/ch11-functional-programming',
#   'homepage': None,
#   'size': 5,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 35,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 35,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 131652054,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzE2NTIwNTQ=',
#   'name': 'ch12-apis',
#   'full_name': 'infx511/ch12-apis',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/ch12-apis',
#   'description': 'Exercises for Chapter 12: Accessing Web APIs',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/ch12-apis',
#   'forks_url': 'https://api.github.com/repos/infx511/ch12-apis/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/ch12-apis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/ch12-apis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/ch12-apis/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/ch12-apis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/ch12-apis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/ch12-apis/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/ch12-apis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/ch12-apis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/ch12-apis/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/ch12-apis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/ch12-apis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/ch12-apis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/ch12-apis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/ch12-apis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/ch12-apis/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/ch12-apis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/ch12-apis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/ch12-apis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/ch12-apis/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/ch12-apis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/ch12-apis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/ch12-apis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/ch12-apis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/ch12-apis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/ch12-apis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/ch12-apis/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/ch12-apis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/ch12-apis/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/ch12-apis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/ch12-apis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/ch12-apis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/ch12-apis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/ch12-apis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/ch12-apis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/ch12-apis/deployments',
#   'created_at': '2018-04-30T22:17:26Z',
#   'updated_at': '2018-04-30T22:18:11Z',
#   'pushed_at': '2018-04-30T22:17:41Z',
#   'git_url': 'git://github.com/infx511/ch12-apis.git',
#   'ssh_url': 'git@github.com:infx511/ch12-apis.git',
#   'clone_url': 'https://github.com/infx511/ch12-apis.git',
#   'svn_url': 'https://github.com/infx511/ch12-apis',
#   'homepage': '',
#   'size': 7,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 21,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 21,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 132497081,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzI0OTcwODE=',
#   'name': 'ch13-git-branches',
#   'full_name': 'infx511/ch13-git-branches',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/ch13-git-branches',
#   'description': 'Exercises for Chapter 13: Git Branches',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/ch13-git-branches',
#   'forks_url': 'https://api.github.com/repos/infx511/ch13-git-branches/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/ch13-git-branches/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/ch13-git-branches/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/ch13-git-branches/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/ch13-git-branches/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/ch13-git-branches/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/ch13-git-branches/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/ch13-git-branches/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/ch13-git-branches/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/ch13-git-branches/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/ch13-git-branches/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/ch13-git-branches/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/ch13-git-branches/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/ch13-git-branches/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/ch13-git-branches/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/ch13-git-branches/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/ch13-git-branches/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/ch13-git-branches/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/ch13-git-branches/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/ch13-git-branches/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/ch13-git-branches/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/ch13-git-branches/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/ch13-git-branches/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/ch13-git-branches/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/ch13-git-branches/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/ch13-git-branches/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/ch13-git-branches/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/ch13-git-branches/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/ch13-git-branches/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/ch13-git-branches/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/ch13-git-branches/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/ch13-git-branches/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/ch13-git-branches/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/ch13-git-branches/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/ch13-git-branches/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/ch13-git-branches/deployments',
#   'created_at': '2018-05-07T17:55:03Z',
#   'updated_at': '2018-05-07T17:55:18Z',
#   'pushed_at': '2018-05-07T17:55:17Z',
#   'git_url': 'git://github.com/infx511/ch13-git-branches.git',
#   'ssh_url': 'git@github.com:infx511/ch13-git-branches.git',
#   'clone_url': 'https://github.com/infx511/ch13-git-branches.git',
#   'svn_url': 'https://github.com/infx511/ch13-git-branches',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 132502976,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzI1MDI5NzY=',
#   'name': 'ch15-oop',
#   'full_name': 'infx511/ch15-oop',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/ch15-oop',
#   'description': 'Exercises for Chapter 15: Object-Oriented Programming',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/ch15-oop',
#   'forks_url': 'https://api.github.com/repos/infx511/ch15-oop/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/ch15-oop/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/ch15-oop/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/ch15-oop/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/ch15-oop/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/ch15-oop/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/ch15-oop/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/ch15-oop/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/ch15-oop/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/ch15-oop/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/ch15-oop/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/ch15-oop/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/ch15-oop/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/ch15-oop/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/ch15-oop/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/ch15-oop/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/ch15-oop/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/ch15-oop/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/ch15-oop/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/ch15-oop/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/ch15-oop/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/ch15-oop/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/ch15-oop/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/ch15-oop/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/ch15-oop/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/ch15-oop/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/ch15-oop/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/ch15-oop/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/ch15-oop/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/ch15-oop/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/ch15-oop/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/ch15-oop/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/ch15-oop/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/ch15-oop/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/ch15-oop/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/ch15-oop/deployments',
#   'created_at': '2018-05-07T18:48:23Z',
#   'updated_at': '2018-05-07T18:48:47Z',
#   'pushed_at': '2018-05-07T18:48:45Z',
#   'git_url': 'git://github.com/infx511/ch15-oop.git',
#   'ssh_url': 'git@github.com:infx511/ch15-oop.git',
#   'clone_url': 'https://github.com/infx511/ch15-oop.git',
#   'svn_url': 'https://github.com/infx511/ch15-oop',
#   'homepage': None,
#   'size': 4,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 133454797,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzM0NTQ3OTc=',
#   'name': 'ch16-pandas',
#   'full_name': 'infx511/ch16-pandas',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/ch16-pandas',
#   'description': 'Exercises for Chapter 16: The pandas Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/ch16-pandas',
#   'forks_url': 'https://api.github.com/repos/infx511/ch16-pandas/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/ch16-pandas/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/ch16-pandas/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/ch16-pandas/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/ch16-pandas/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/ch16-pandas/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/ch16-pandas/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/ch16-pandas/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/ch16-pandas/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/ch16-pandas/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/ch16-pandas/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/ch16-pandas/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/ch16-pandas/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/ch16-pandas/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/ch16-pandas/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/ch16-pandas/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/ch16-pandas/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/ch16-pandas/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/ch16-pandas/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/ch16-pandas/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/ch16-pandas/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/ch16-pandas/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/ch16-pandas/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/ch16-pandas/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/ch16-pandas/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/ch16-pandas/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/ch16-pandas/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/ch16-pandas/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/ch16-pandas/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/ch16-pandas/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/ch16-pandas/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/ch16-pandas/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/ch16-pandas/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/ch16-pandas/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/ch16-pandas/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/ch16-pandas/deployments',
#   'created_at': '2018-05-15T03:35:14Z',
#   'updated_at': '2018-05-15T03:35:35Z',
#   'pushed_at': '2018-05-15T03:35:34Z',
#   'git_url': 'git://github.com/infx511/ch16-pandas.git',
#   'ssh_url': 'git@github.com:infx511/ch16-pandas.git',
#   'clone_url': 'https://github.com/infx511/ch16-pandas.git',
#   'svn_url': 'https://github.com/infx511/ch16-pandas',
#   'homepage': None,
#   'size': 22,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 16,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 16,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 133728629,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzM3Mjg2Mjk=',
#   'name': 'ch17-javascript',
#   'full_name': 'infx511/ch17-javascript',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/ch17-javascript',
#   'description': 'Exercises for Chapter 17: JavaScript',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/ch17-javascript',
#   'forks_url': 'https://api.github.com/repos/infx511/ch17-javascript/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/ch17-javascript/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/ch17-javascript/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/ch17-javascript/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/ch17-javascript/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/ch17-javascript/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/ch17-javascript/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/ch17-javascript/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/ch17-javascript/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/ch17-javascript/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/ch17-javascript/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/ch17-javascript/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/ch17-javascript/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/ch17-javascript/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/ch17-javascript/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/ch17-javascript/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/ch17-javascript/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/ch17-javascript/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/ch17-javascript/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/ch17-javascript/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/ch17-javascript/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/ch17-javascript/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/ch17-javascript/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/ch17-javascript/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/ch17-javascript/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/ch17-javascript/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/ch17-javascript/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/ch17-javascript/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/ch17-javascript/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/ch17-javascript/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/ch17-javascript/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/ch17-javascript/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/ch17-javascript/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/ch17-javascript/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/ch17-javascript/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/ch17-javascript/deployments',
#   'created_at': '2018-05-16T22:15:40Z',
# ...
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/ch9-dictionaries',
#   'description': 'Exercises for Chapter 9: Dictionaries',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/ch9-dictionaries',
#   'forks_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/ch9-dictionaries/deployments',
#   'created_at': '2018-04-16T15:21:41Z',
#   'updated_at': '2018-04-16T15:21:57Z',
#   'pushed_at': '2018-04-16T15:21:55Z',
#   'git_url': 'git://github.com/infx511/ch9-dictionaries.git',
#   'ssh_url': 'git@github.com:infx511/ch9-dictionaries.git',
#   'clone_url': 'https://github.com/infx511/ch9-dictionaries.git',
#   'svn_url': 'https://github.com/infx511/ch9-dictionaries',
#   'homepage': None,
#   'size': 334,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 38,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 38,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 125927664,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMjU5Mjc2NjQ=',
#   'name': 'infx511.github.io',
#   'full_name': 'infx511/infx511.github.io',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/infx511.github.io',
#   'description': 'Course book for INFX 511: Introduction to Programming for Data Science and Visualization. https://infx511.github.io',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/infx511.github.io',
#   'forks_url': 'https://api.github.com/repos/infx511/infx511.github.io/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/infx511.github.io/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/infx511.github.io/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/infx511.github.io/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/infx511.github.io/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/infx511.github.io/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/infx511.github.io/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/infx511.github.io/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/infx511.github.io/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/infx511.github.io/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/infx511.github.io/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/infx511.github.io/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/infx511.github.io/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/infx511.github.io/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/infx511.github.io/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/infx511.github.io/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/infx511.github.io/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/infx511.github.io/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/infx511.github.io/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/infx511.github.io/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/infx511.github.io/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/infx511.github.io/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/infx511.github.io/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/infx511.github.io/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/infx511.github.io/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/infx511.github.io/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/infx511.github.io/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/infx511.github.io/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/infx511.github.io/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/infx511.github.io/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/infx511.github.io/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/infx511.github.io/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/infx511.github.io/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/infx511.github.io/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/infx511.github.io/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/infx511.github.io/deployments',
#   'created_at': '2018-03-19T22:19:32Z',
#   'updated_at': '2018-05-16T19:31:06Z',
#   'pushed_at': '2018-05-16T19:31:05Z',
#   'git_url': 'git://github.com/infx511/infx511.github.io.git',
#   'ssh_url': 'git@github.com:infx511/infx511.github.io.git',
#   'clone_url': 'https://github.com/infx511/infx511.github.io.git',
#   'svn_url': 'https://github.com/infx511/infx511.github.io',
#   'homepage': None,
#   'size': 12306,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'HTML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 126063435,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMjYwNjM0MzU=',
#   'name': 'remote_practice',
#   'full_name': 'infx511/remote_practice',
#   'private': False,
#   'owner': {'login': 'infx511',
#    'id': 34052090,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDUyMDkw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34052090?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infx511',
#    'html_url': 'https://github.com/infx511',
#    'followers_url': 'https://api.github.com/users/infx511/followers',
#    'following_url': 'https://api.github.com/users/infx511/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/infx511/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/infx511/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/infx511/subscriptions',
#    'organizations_url': 'https://api.github.com/users/infx511/orgs',
#    'repos_url': 'https://api.github.com/users/infx511/repos',
#    'events_url': 'https://api.github.com/users/infx511/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/infx511/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/infx511/remote_practice',
#   'description': 'An example repo for practicing with GitHub remotes',
#   'fork': False,
#   'url': 'https://api.github.com/repos/infx511/remote_practice',
#   'forks_url': 'https://api.github.com/repos/infx511/remote_practice/forks',
#   'keys_url': 'https://api.github.com/repos/infx511/remote_practice/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/infx511/remote_practice/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/infx511/remote_practice/teams',
#   'hooks_url': 'https://api.github.com/repos/infx511/remote_practice/hooks',
#   'issue_events_url': 'https://api.github.com/repos/infx511/remote_practice/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/infx511/remote_practice/events',
#   'assignees_url': 'https://api.github.com/repos/infx511/remote_practice/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/infx511/remote_practice/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/infx511/remote_practice/tags',
#   'blobs_url': 'https://api.github.com/repos/infx511/remote_practice/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/infx511/remote_practice/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/infx511/remote_practice/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/infx511/remote_practice/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/infx511/remote_practice/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/infx511/remote_practice/languages',
#   'stargazers_url': 'https://api.github.com/repos/infx511/remote_practice/stargazers',
#   'contributors_url': 'https://api.github.com/repos/infx511/remote_practice/contributors',
#   'subscribers_url': 'https://api.github.com/repos/infx511/remote_practice/subscribers',
#   'subscription_url': 'https://api.github.com/repos/infx511/remote_practice/subscription',
#   'commits_url': 'https://api.github.com/repos/infx511/remote_practice/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/infx511/remote_practice/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/infx511/remote_practice/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/infx511/remote_practice/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/infx511/remote_practice/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/infx511/remote_practice/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/infx511/remote_practice/merges',
#   'archive_url': 'https://api.github.com/repos/infx511/remote_practice/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/infx511/remote_practice/downloads',
#   'issues_url': 'https://api.github.com/repos/infx511/remote_practice/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/infx511/remote_practice/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/infx511/remote_practice/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/infx511/remote_practice/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/infx511/remote_practice/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/infx511/remote_practice/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/infx511/remote_practice/deployments',
#   'created_at': '2018-03-20T18:19:46Z',
#   'updated_at': '2018-03-20T18:21:09Z',
#   'pushed_at': '2018-03-20T18:21:08Z',
#   'git_url': 'git://github.com/infx511/remote_practice.git',
#   'ssh_url': 'git@github.com:infx511/remote_practice.git',
#   'clone_url': 'https://github.com/infx511/remote_practice.git',
#   'svn_url': 'https://github.com/infx511/remote_practice',
#   'homepage': None,
#   'size': 1,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 12,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 12,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'}]

# %% [markdown]
# ## Flattening nested JSON data to work with it

# %%
#Check out documentation: https://developer.github.com/v3/
#Check out parameters section!

resource_uri = "https://api.github.com/search/repositories"
query_params = {'q': 'd3', 'sort': 'stars'}

# %%
response = requests.get(resource_uri, params = query_params)
response.url #confirm url
# Out:
# 'https://api.github.com/search/repositories?q=d3&sort=stars'

# %%
data = response.json() #extract data

# %%
print(data.keys())  #start exploring this data
    # dict_keys(['total_count', 'incomplete_results', 'items'])
    # looking at the JSON data itself (e.g., in the browser), 
    # `items` is the key that contains the value you want
# Out:
# dict_keys(['total_count', 'incomplete_results', 'items'])

# %%
result_items = data['items']  # "flatten" into new variable
print(len(result_items))  # 30, number of results returned
# Out:
# 30

# %%
#When exploring, make intermediate variables
first_item = result_items[0]
first_item
# Out:
# {'id': 28457823,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyODQ1NzgyMw==',
#  'name': 'freeCodeCamp',
#  'full_name': 'freeCodeCamp/freeCodeCamp',
#  'private': False,
#  'owner': {'login': 'freeCodeCamp',
#   'id': 9892522,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk4OTI1MjI=',
#   'avatar_url': 'https://avatars0.githubusercontent.com/u/9892522?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/freeCodeCamp',
#   'html_url': 'https://github.com/freeCodeCamp',
#   'followers_url': 'https://api.github.com/users/freeCodeCamp/followers',
#   'following_url': 'https://api.github.com/users/freeCodeCamp/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/freeCodeCamp/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/freeCodeCamp/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/freeCodeCamp/subscriptions',
#   'organizations_url': 'https://api.github.com/users/freeCodeCamp/orgs',
#   'repos_url': 'https://api.github.com/users/freeCodeCamp/repos',
#   'events_url': 'https://api.github.com/users/freeCodeCamp/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/freeCodeCamp/received_events',
#   'type': 'Organization',
#   'site_admin': False},
#  'html_url': 'https://github.com/freeCodeCamp/freeCodeCamp',
#  'description': 'The https://www.freeCodeCamp.org open source codebase and curriculum. Learn to code for free together with millions of people.',
#  'fork': False,
#  'url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp',
#  'forks_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/forks',
#  'keys_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/teams',
#  'hooks_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/hooks',
#  'issue_events_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/events',
#  'assignees_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/tags',
#  'blobs_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/languages',
#  'stargazers_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/stargazers',
#  'contributors_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/contributors',
#  'subscribers_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/subscribers',
#  'subscription_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/subscription',
#  'commits_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/merges',
#  'archive_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/downloads',
#  'issues_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/freeCodeCamp/freeCodeCamp/deployments',
#  'created_at': '2014-12-24T17:49:19Z',
#  'updated_at': '2019-03-03T01:11:36Z',
#  'pushed_at': '2019-03-02T21:04:16Z',
#  'git_url': 'git://github.com/freeCodeCamp/freeCodeCamp.git',
#  'ssh_url': 'git@github.com:freeCodeCamp/freeCodeCamp.git',
#  'clone_url': 'https://github.com/freeCodeCamp/freeCodeCamp.git',
#  'svn_url': 'https://github.com/freeCodeCamp/freeCodeCamp',
#  'homepage': '',
#  'size': 112492,
#  'stargazers_count': 297686,
#  'watchers_count': 297686,
#  'language': 'JavaScript',
#  'has_issues': True,
#  'has_projects': False,
#  'has_downloads': True,
#  'has_wiki': False,
#  'has_pages': False,
#  'forks_count': 21006,
#  'mirror_url': None,
#  'archived': False,
#  'open_issues_count': 4115,
#  'license': {'key': 'bsd-3-clause',
#   'name': 'BSD 3-Clause "New" or "Revised" License',
#   'spdx_id': 'BSD-3-Clause',
#   'url': 'https://api.github.com/licenses/bsd-3-clause',
#   'node_id': 'MDc6TGljZW5zZTU='},
#  'forks': 21006,
#  'open_issues': 4115,
#  'watchers': 297686,
#  'default_branch': 'master',
#  'score': 51.461067}
